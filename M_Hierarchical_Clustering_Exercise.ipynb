# %% [markdown]
# <a href="https://colab.research.google.com/github/Khuzamaalk/T5_BootCamp/blob/main/M_Hierarchical_Clustering_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Python Implementation using the scikit-learn library**

# %% [markdown]
# #Step 1 : import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

# %% [markdown]
# #Step 2 : Randomly chosen dataset

# %%
# Generate sample data
X, y = make_blobs(n_samples=20, centers=3, cluster_std=0.60, random_state=0)

# %% [markdown]
# #Step 3 : Perform hierarchical clustering  + Ploting

# %%
# Generate the linkage matrix
Z = linkage(X, method='ward')

# Plot the dendrogram
plt.figure(figsize=(10, 7))
dendrogram(Z)
plt.title('Dendrogram')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
